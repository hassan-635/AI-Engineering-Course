# %%
import numpy as np

# %%
A = np.array(([1, 2], [3, 4]))
determinant = np.linalg.det(A)
determinant
# Out:
# np.float64(-2.0000000000000004)

# %%
inverse = np.linalg.inv(A)
inverse
# Out:
# array([[-2. ,  1. ],
#        [ 1.5, -0.5]])
