# %% [markdown]
# # import libraries :

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load Dataset :

# %%
data = pd.load_data("Week_2_Data_Science_Essentials/day7_EDA_Project/titanic.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 data = pd.load_data("Week_2_Data_Science_Essentials/day7_EDA_Project/titanic.csv")
#
# AttributeError: module 'pandas' has no attribute 'load_data'

# %% [markdown]
# # Data Cleaning :
